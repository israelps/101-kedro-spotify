# %%
import pandas as pd
import numpy as np

# %%
# %reload_kedro
catalog.list()
# Out:
# 2021-12-16 09:50:11,707 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2021-12-16 09:50:11,736 - root - INFO - ** Kedro project 101-kedro-spotify
# 2021-12-16 09:50:11,737 - root - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`
# 2021-12-16 09:50:11,748 - root - INFO - Registered line magic `run_viz`
# ['song_info',
#  'song_metrics',
#  'song_popularity',
#  'prm_spotify_data',
#  'parameters',
#  'params:index_col']

# %%
song_info = catalog.load('song_info')
song_metrics = catalog.load('song_metrics')
song_popularity = catalog.load('song_popularity')
# Out:
# 2021-12-16 09:50:24,053 - kedro.io.data_catalog - INFO - Loading data from `song_info` (CSVDataSet)...
# 2021-12-16 09:50:24,304 - kedro.io.data_catalog - INFO - Loading data from `song_metrics` (CSVDataSet)...
# 2021-12-16 09:50:24,484 - kedro.io.data_catalog - INFO - Loading data from `song_popularity` (CSVDataSet)...

# %%
song_info.join(song_metrics, how='left').join(song_popularity, how='left')
# Out:
#                                               artists  \
# id
# 7pQSmQ0l7QdBeL9X6CEMbH              ['Erroll Garner']
# 2g8MTBFRUSFKbY5RQiSSEE            ['Maison & Dragen']
# 2LcJoQ5SDUZrC2qUjWMEdF  ['Yoel Lerner', 'Mazi Cohen']
# 6RzHyUtRNARYyn2AIuoLnY           ['Barbra Streisand']
# 6Kd0I5es8911FZpYhFS053              ['Willie Nelson']
# ...                                               ...
# 0ognkBvJqaov2gWDgaMzvz           ['System Of A Down']
# 2B8TnS5nJijlzuORGs3RKy                  ['Taj Mahal']
# 5n5uyFpfopa4mNdSN0gTaH    ['Macklemore & Ryan Lewis']
# 0MrZG1nTNQVzeSJKi6gFVF                     ['Eagles']
# 2t47pq6bqRZgHdq263KxPy      ['Lorenzo De Monteclaro']
#
#                                                                      name  \
# id
# 7pQSmQ0l7QdBeL9X6CEMbH  I'll Remember April - Original Edited Concert ...
# 2g8MTBFRUSFKbY5RQiSSEE                      Chinese New Year - Radio Edit
# 2LcJoQ5SDUZrC2qUjWMEdF                                          השפן הקטן
# ...

# %%
ds[['id','artists','name','year','release_date']].to_csv('../data/01_raw/song_info.csv', index=False)
ds.drop(['artists','name','year','release_date','popularity'], axis=1).to_csv('../data/01_raw/song_metrics.csv', index=False)
ds[['id','popularity']].to_csv('../data/01_raw/song_popularity.csv', index=False)
